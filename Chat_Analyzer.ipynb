# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
from pickle import encode_long
df=pd.read_fwf('/content/drive/MyDrive/Dataset/ML Projects/Chat Analyzer/WhatsApp Chat with 4 idiotz.txt',encode_long='utf-8')
df
# Out:
#       3/20/21, 22:09 - You created group "3 idiotz"
# 0             6/26/22, 20:45 - You added Hasham Uni
# 1                       6/26/22, 20:45 - Fadii left
# 2        7/3/22, 01:33 - Usama Uni: <Media omitted>
# 3        7/3/22, 01:33 - Usama Uni: <Media omitted>
# 4        7/3/22, 01:33 - Usama Uni: <Media omitted>
# ...                                             ...
# 2287  8/19/23, 11:57 - Hasham Uni: Allah janat nase
# 2288  8/19/23, 11:58 - Hasham Uni: Bohat acha larka
# 2289                8/19/23, 12:12 - Fawad: Ameen 🫂
# 2290    8/19/23, 16:43 - Hamza Uni: <Media omitted>
# 2291                   8/20/23, 17:41 - Fawad: null
#
# [2292 rows x 1 columns]

# %%
df['3/20/21, 22:09 - You created group "3 idiotz"'][1616]
# Out:
# 'for (int i = targs->start_index; i <= tar'

# %%
# pattern='\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'
# pattern

# %%
import re

# %%
# # messages = re.split(pattern, str(df))
# # dates = re.findall(pattern, str(df))
# messages = re.sub("[^a-zA-Z]",  # Search for all non-letters
#                           " ",          # Replace all non-letters with spaces
#                           str(df))

# %%
# dates

# %%
# messages

# %%
# messages=messages.split('n')

# %%
df
# Out:
#       3/20/21, 22:09 - You created group "3 idiotz"
# 0             6/26/22, 20:45 - You added Hasham Uni
# 1                       6/26/22, 20:45 - Fadii left
# 2        7/3/22, 01:33 - Usama Uni: <Media omitted>
# 3        7/3/22, 01:33 - Usama Uni: <Media omitted>
# 4        7/3/22, 01:33 - Usama Uni: <Media omitted>
# ...                                             ...
# 2287  8/19/23, 11:57 - Hasham Uni: Allah janat nase
# 2288  8/19/23, 11:58 - Hasham Uni: Bohat acha larka
# 2289                8/19/23, 12:12 - Fawad: Ameen 🫂
# 2290    8/19/23, 16:43 - Hamza Uni: <Media omitted>
# 2291                   8/20/23, 17:41 - Fawad: null
#
# [2292 rows x 1 columns]

# %%
# # df = pd.DataFrame({'user_message': messages, 'message_date': dates})
# df = pd.DataFrame({'user_message': df})
# df[['user_message']]

# %%
# convert message_date type
# df['message_date'] = pd.to_datetime(df['message_date'], format='%m/%d/%Y, %H:%M - ')
# df['message_date'] = pd.to_datetime(df['message_date'])
df.rename(columns={'3/20/21, 22:09 - You created group "3 idiotz"': 'user_message'}, inplace=True)

# %%
df
# Out:
#                                        user_message
# 0             6/26/22, 20:45 - You added Hasham Uni
# 1                       6/26/22, 20:45 - Fadii left
# 2        7/3/22, 01:33 - Usama Uni: <Media omitted>
# 3        7/3/22, 01:33 - Usama Uni: <Media omitted>
# 4        7/3/22, 01:33 - Usama Uni: <Media omitted>
# ...                                             ...
# 2287  8/19/23, 11:57 - Hasham Uni: Allah janat nase
# 2288  8/19/23, 11:58 - Hasham Uni: Bohat acha larka
# 2289                8/19/23, 12:12 - Fawad: Ameen 🫂
# 2290    8/19/23, 16:43 - Hamza Uni: <Media omitted>
# 2291                   8/20/23, 17:41 - Fawad: null
#
# [2292 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2292 entries, 0 to 2291
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_message  2292 non-null   object
# dtypes: object(1)
# memory usage: 18.0+ KB

# %%
df['message_date']=df['user_message'].str.split('-').str.get(0)
df
# Out:
#                                        user_message     message_date
# 0             6/26/22, 20:45 - You added Hasham Uni  6/26/22, 20:45
# 1                       6/26/22, 20:45 - Fadii left  6/26/22, 20:45
# 2        7/3/22, 01:33 - Usama Uni: <Media omitted>   7/3/22, 01:33
# 3        7/3/22, 01:33 - Usama Uni: <Media omitted>   7/3/22, 01:33
# 4        7/3/22, 01:33 - Usama Uni: <Media omitted>   7/3/22, 01:33
# ...                                             ...              ...
# 2287  8/19/23, 11:57 - Hasham Uni: Allah janat nase  8/19/23, 11:57
# 2288  8/19/23, 11:58 - Hasham Uni: Bohat acha larka  8/19/23, 11:58
# 2289                8/19/23, 12:12 - Fawad: Ameen 🫂  8/19/23, 12:12
# 2290    8/19/23, 16:43 - Hamza Uni: <Media omitted>  8/19/23, 16:43
# 2291                   8/20/23, 17:41 - Fawad: null  8/20/23, 17:41
#
# [2292 rows x 2 columns]

# %%
df['user_message']=df['user_message'].str.split('-').str.get(1)
df
# Out:
#                        user_message     message_date
# 0              You added Hasham Uni  6/26/22, 20:45
# 1                        Fadii left  6/26/22, 20:45
# 2        Usama Uni: <Media omitted>   7/3/22, 01:33
# 3        Usama Uni: <Media omitted>   7/3/22, 01:33
# 4        Usama Uni: <Media omitted>   7/3/22, 01:33
# ...                             ...              ...
# 2287   Hasham Uni: Allah janat nase  8/19/23, 11:57
# 2288   Hasham Uni: Bohat acha larka  8/19/23, 11:58
# 2289                 Fawad: Ameen 🫂  8/19/23, 12:12
# 2290     Hamza Uni: <Media omitted>  8/19/23, 16:43
# 2291                    Fawad: null  8/20/23, 17:41
#
# [2292 rows x 2 columns]

# %%
# users = []
# messages = []
# for message in df['user_message']:
#   # entry = re.split('([\w\W]+?):\s', message)
#   entry = df['user_message'].str.split(':')
#   # df['user_message'].str.split(':').str.get(0)
#   print(entry)
#   print(entry[0])
#   print('here')
#   print(df['user_message'].str.split(':').str.get(0).str.split(','))
#   if entry.str.split(','):  # user name
#     users.append(entry[1])
#     messages.append(" ".join(entry[2:]))
#   else:
#     users.append('group_notification')
#     messages.append(entry[0])
# df['user'] = users
# df['message'] = messages
# #   if entry[1:]:  # user name
# #     users.append(entry[1])
# #     messages.append(" ".join(entry[2:]))
# #   else:
# #     users.append('group_notification')
# #     messages.append(entry[0])
# # df['user'] = users
# # df['message'] = messages

# %%
# df["message_date"] = df["message_date"].astype('datetime64[ns]')

# %%
df['message_date'][0]
# Out:
# '6/26/22, 20:45 '

# %%
# pd.to_datetime(df['message_date'], format='%m/%d/%Y, %H:%M - ')
# pd.to_datetime(df['message_date'], format='6/26/22, 20:45 ')
# pd.to_datetime(df['message_date'], format='%m/%d/22, %H:%M ')
df['message_date'] = pd.to_datetime(df['message_date'].str.strip(), format='%m/%d/%y, %H:%M', errors='coerce')

# %%
# df.rename(columns={'message_date','date'}, axis=1, inplace=True)

# %%
df
# Out:
#                        user_message        message_date
# 0              You added Hasham Uni 2022-06-26 20:45:00
# 1                        Fadii left 2022-06-26 20:45:00
# 2        Usama Uni: <Media omitted> 2022-07-03 01:33:00
# 3        Usama Uni: <Media omitted> 2022-07-03 01:33:00
# 4        Usama Uni: <Media omitted> 2022-07-03 01:33:00
# ...                             ...                 ...
# 2287   Hasham Uni: Allah janat nase 2023-08-19 11:57:00
# 2288   Hasham Uni: Bohat acha larka 2023-08-19 11:58:00
# 2289                 Fawad: Ameen 🫂 2023-08-19 12:12:00
# 2290     Hamza Uni: <Media omitted> 2023-08-19 16:43:00
# 2291                    Fawad: null 2023-08-20 17:41:00
#
# [2292 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2292 entries, 0 to 2291
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_message  1722 non-null   object
#  1   message_date  1691 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 35.9+ KB

# %%
df.isnull().sum()
# Out:
# user_message    570
# message_date    601
# dtype: int64

# %%
df['user']=df['user_message'].str.split(':').str.get(0)
df['message']=df['user_message'].str.split(':').str.get(1)

# %%
# df['only_category']=np.where(df['message'].isnull(),df['user'],np.where(df['message'] in df['user'],'group notificaion',df['message']))
df['message2']=np.where(df['message'].isnull(),df['user'],df['message'])

# %%
df
# Out:
#                        user_message        message_date  \
# 0              You added Hasham Uni 2022-06-26 20:45:00
# 1                        Fadii left 2022-06-26 20:45:00
# 2        Usama Uni: <Media omitted> 2022-07-03 01:33:00
# 3        Usama Uni: <Media omitted> 2022-07-03 01:33:00
# 4        Usama Uni: <Media omitted> 2022-07-03 01:33:00
# ...                             ...                 ...
# 2287   Hasham Uni: Allah janat nase 2023-08-19 11:57:00
# 2288   Hasham Uni: Bohat acha larka 2023-08-19 11:58:00
# 2289                 Fawad: Ameen 🫂 2023-08-19 12:12:00
# 2290     Hamza Uni: <Media omitted> 2023-08-19 16:43:00
# 2291                    Fawad: null 2023-08-20 17:41:00
#
#                        user            message               message2
# 0      You added Hasham Uni                NaN   You added Hasham Uni
# 1                Fadii left                NaN             Fadii left
# 2                 Usama Uni    <Media omitted>        <Media omitted>
# 3                 Usama Uni    <Media omitted>        <Media omitted>
# 4                 Usama Uni    <Media omitted>        <Media omitted>
# ...                     ...                ...                    ...
# 2287             Hasham Uni   Allah janat nase       Allah janat nase
# 2288             Hasham Uni   Bohat acha larka       Bohat acha larka
# 2289                  Fawad            Ameen 🫂                Ameen 🫂
# 2290              Hamza Uni    <Media omitted>        <Media omitted>
# 2291                  Fawad               null                   null
#
# [2292 rows x 5 columns]

# %%
# a='Nan'
# msg=[]
# print(a)
# print(type(a))
# for i in range(df['message'].shape[0]):
#   print(i)
#   print('user',df['user'][i])
#   print('message',df['message'][i])
#   df['message'].apply(lambda x: 'Nan' if ['user'][i] == ['message'][i] else df['user'][i])
#   # msg.append(df['message'].apply(lambda x: df['user'][i] if x ==a else df['message'][i]))
#   # df['message'][i]=msg[i]
# msg

# %%
# df['msg']=msg

# %%
df
# Out:
#                        user_message        message_date  \
# 0              You added Hasham Uni 2022-06-26 20:45:00
# 1                        Fadii left 2022-06-26 20:45:00
# 2        Usama Uni: <Media omitted> 2022-07-03 01:33:00
# 3        Usama Uni: <Media omitted> 2022-07-03 01:33:00
# 4        Usama Uni: <Media omitted> 2022-07-03 01:33:00
# ...                             ...                 ...
# 2287   Hasham Uni: Allah janat nase 2023-08-19 11:57:00
# 2288   Hasham Uni: Bohat acha larka 2023-08-19 11:58:00
# 2289                 Fawad: Ameen 🫂 2023-08-19 12:12:00
# 2290     Hamza Uni: <Media omitted> 2023-08-19 16:43:00
# 2291                    Fawad: null 2023-08-20 17:41:00
#
#                        user            message               message2
# 0      You added Hasham Uni                NaN   You added Hasham Uni
# 1                Fadii left                NaN             Fadii left
# 2                 Usama Uni    <Media omitted>        <Media omitted>
# 3                 Usama Uni    <Media omitted>        <Media omitted>
# 4                 Usama Uni    <Media omitted>        <Media omitted>
# ...                     ...                ...                    ...
# 2287             Hasham Uni   Allah janat nase       Allah janat nase
# 2288             Hasham Uni   Bohat acha larka       Bohat acha larka
# 2289                  Fawad            Ameen 🫂                Ameen 🫂
# 2290              Hamza Uni    <Media omitted>        <Media omitted>
# 2291                  Fawad               null                   null
#
# [2292 rows x 5 columns]

# %%
df['message'].fillna('Group Notification',inplace=True)

# %%
df.isnull().sum()
# Out:
# user_message    570
# message_date    601
# user            570
# message           0
# message2        570
# dtype: int64

# %%
# df=df.dropna()

# %%
df['only_date'] = df['message_date'].dt.date
df['year'] = df['message_date'].dt.year
df['month_num'] = df['message_date'].dt.month
df['month'] = df['message_date'].dt.month_name()
df['day'] = df['message_date'].dt.day
df['day_name'] = df['message_date'].dt.day_name()
df['hour'] = df['message_date'].dt.hour
df['minute'] = df['message_date'].dt.minute

# %%
df.drop(columns=['message_date','user_message','message'],inplace=True)

# %%
df
# Out:
#                        user               message2   only_date    year  \
# 0      You added Hasham Uni   You added Hasham Uni  2022-06-26  2022.0
# 1                Fadii left             Fadii left  2022-06-26  2022.0
# 2                 Usama Uni        <Media omitted>  2022-07-03  2022.0
# 3                 Usama Uni        <Media omitted>  2022-07-03  2022.0
# 4                 Usama Uni        <Media omitted>  2022-07-03  2022.0
# ...                     ...                    ...         ...     ...
# 2287             Hasham Uni       Allah janat nase  2023-08-19  2023.0
# 2288             Hasham Uni       Bohat acha larka  2023-08-19  2023.0
# 2289                  Fawad                Ameen 🫂  2023-08-19  2023.0
# 2290              Hamza Uni        <Media omitted>  2023-08-19  2023.0
# 2291                  Fawad                   null  2023-08-20  2023.0
#
#       month_num   month   day  day_name  hour  minute
# 0           6.0    June  26.0    Sunday  20.0    45.0
# 1           6.0    June  26.0    Sunday  20.0    45.0
# 2           7.0    July   3.0    Sunday   1.0    33.0
# 3           7.0    July   3.0    Sunday   1.0    33.0
# 4           7.0    July   3.0    Sunday   1.0    33.0
# ...         ...     ...   ...       ...   ...     ...
# 2287        8.0  August  19.0  Saturday  11.0    57.0
# 2288        8.0  August  19.0  Saturday  11.0    58.0
# 2289        8.0  August  19.0  Saturday  12.0    12.0
# 2290        8.0  August  19.0  Saturday  16.0    43.0
# 2291        8.0  August  20.0    Sunday  17.0    41.0
#
# [2292 rows x 10 columns]

# %%
np.where(df['user'] == df['message2'],print('haha'),print('bandyal'))
# newdf=df[df['user']==df['message2']]
# newdf.shape
# Out:
# haha
# bandyal
# array([None, None, None, ..., None, None, None], dtype=object)

# %%
# df['user'].apply(lambda x: 'Null' if df['user'] == df['message2'] else x )
df['user'] = np.where(df['user'] == df['message2'], 'Group Notification', df['user'])

# %%
df
# Out:
#                     user               message2   only_date    year  \
# 0     Group Notification   You added Hasham Uni  2022-06-26  2022.0
# 1     Group Notification             Fadii left  2022-06-26  2022.0
# 2              Usama Uni        <Media omitted>  2022-07-03  2022.0
# 3              Usama Uni        <Media omitted>  2022-07-03  2022.0
# 4              Usama Uni        <Media omitted>  2022-07-03  2022.0
# ...                  ...                    ...         ...     ...
# 2287          Hasham Uni       Allah janat nase  2023-08-19  2023.0
# 2288          Hasham Uni       Bohat acha larka  2023-08-19  2023.0
# 2289               Fawad                Ameen 🫂  2023-08-19  2023.0
# 2290           Hamza Uni        <Media omitted>  2023-08-19  2023.0
# 2291               Fawad                   null  2023-08-20  2023.0
#
#       month_num   month   day  day_name  hour  minute
# 0           6.0    June  26.0    Sunday  20.0    45.0
# 1           6.0    June  26.0    Sunday  20.0    45.0
# 2           7.0    July   3.0    Sunday   1.0    33.0
# 3           7.0    July   3.0    Sunday   1.0    33.0
# 4           7.0    July   3.0    Sunday   1.0    33.0
# ...         ...     ...   ...       ...   ...     ...
# 2287        8.0  August  19.0  Saturday  11.0    57.0
# 2288        8.0  August  19.0  Saturday  11.0    58.0
# 2289        8.0  August  19.0  Saturday  12.0    12.0
# 2290        8.0  August  19.0  Saturday  16.0    43.0
# 2291        8.0  August  20.0    Sunday  17.0    41.0
#
# [2292 rows x 10 columns]

# %%
#Total Messages
df['user'].shape
# Out:
# (2292,)

# %%
#Total Number of messages by different users
df['user'].value_counts()
# Out:
#  Fawad                656
#  Usama Uni            504
#  Hasham Uni           307
#  Hamza Uni            222
# Group Notification     33
# Name: user, dtype: int64

# %%
# Group Notification
df[df['user']=='Group Notification']
# Out:
#                     user                message2   only_date    year  \
# 0     Group Notification    You added Hasham Uni  2022-06-26  2022.0
# 1     Group Notification              Fadii left  2022-06-26  2022.0
# 590   Group Notification                     8">         NaT     NaN
# 591   Group Notification                equiv="X         NaT     NaN
# 729   Group Notification                      5?         NaT     NaN
# 975   Group Notification                                 NaT     NaN
# 980   Group Notification                                 NaT     NaN
# 1439  Group Notification                      9n         NaT     NaN
# 1457  Group Notification                     end         NaT     NaN
# 1458  Group Notification                     the         NaT     NaN
# 1468  Group Notification                      ZI         NaT     NaN
# 1472  Group Notification                                 NaT     NaN
# 1474  Group Notification               bWYTCToIf         NaT     NaN
# 1488  Group Notification                      F4         NaT     NaN
# 1494  Group Notification                  6FPK6E         NaT     NaN
# 1496  Group Notification                      F6         NaT     NaN
# 1498  Group Notification                   KdGt0         NaT     NaN
# 1616  Group Notification  >start_index; i <= tar         NaT     NaN
# 1617  Group Notification           >y[i] = targs         NaT     NaN
# 1618  Group Notification                  >y[i];         NaT     NaN
# 1620  Group Notification   >avg) += sum / (targs         NaT     NaN
# 1720  Group Notification                                 NaT     NaN
# 1722  Group Notification          Processed data         NaT     NaN
# 1727  Group Notification                                 NaT     NaN
# 2067  Group Notification                      ZI         NaT     NaN
# 2071  Group Notification                                 NaT     NaN
# 2073  Group Notification               bWYTCToIf         NaT     NaN
# 2087  Group Notification                      F4         NaT     NaN
# 2093  Group Notification                  6FPK6E         NaT     NaN
# 2095  Group Notification                      F6         NaT     NaN
# 2097  Group Notification                   KdGt0         NaT     NaN
# 2142  Group Notification                                 NaT     NaN
# 2250  Group Notification                     489         NaT     NaN
#
#       month_num month   day day_name  hour  minute
# 0           6.0  June  26.0   Sunday  20.0    45.0
# 1           6.0  June  26.0   Sunday  20.0    45.0
# 590         NaN   NaN   NaN      NaN   NaN     NaN
# 591         NaN   NaN   NaN      NaN   NaN     NaN
# 729         NaN   NaN   NaN      NaN   NaN     NaN
# 975         NaN   NaN   NaN      NaN   NaN     NaN
# 980         NaN   NaN   NaN      NaN   NaN     NaN
# 1439        NaN   NaN   NaN      NaN   NaN     NaN
# 1457        NaN   NaN   NaN      NaN   NaN     NaN
# 1458        NaN   NaN   NaN      NaN   NaN     NaN
# 1468        NaN   NaN   NaN      NaN   NaN     NaN
# 1472        NaN   NaN   NaN      NaN   NaN     NaN
# 1474        NaN   NaN   NaN      NaN   NaN     NaN
# 1488        NaN   NaN   NaN      NaN   NaN     NaN
# 1494        NaN   NaN   NaN      NaN   NaN     NaN
# 1496        NaN   NaN   NaN      NaN   NaN     NaN
# 1498        NaN   NaN   NaN      NaN   NaN     NaN
# 1616        NaN   NaN   NaN      NaN   NaN     NaN
# 1617        NaN   NaN   NaN      NaN   NaN     NaN
# 1618        NaN   NaN   NaN      NaN   NaN     NaN
# 1620        NaN   NaN   NaN      NaN   NaN     NaN
# 1720        NaN   NaN   NaN      NaN   NaN     NaN
# 1722        NaN   NaN   NaN      NaN   NaN     NaN
# 1727        NaN   NaN   NaN      NaN   NaN     NaN
# 2067        NaN   NaN   NaN      NaN   NaN     NaN
# 2071        NaN   NaN   NaN      NaN   NaN     NaN
# 2073        NaN   NaN   NaN      NaN   NaN     NaN
# 2087        NaN   NaN   NaN      NaN   NaN     NaN
# 2093        NaN   NaN   NaN      NaN   NaN     NaN
# 2095        NaN   NaN   NaN      NaN   NaN     NaN
# 2097        NaN   NaN   NaN      NaN   NaN     NaN
# 2142        NaN   NaN   NaN      NaN   NaN     NaN
# 2250        NaN   NaN   NaN      NaN   NaN     NaN

# %%
# number of Group Notification
df[df['user']=='Group Notification'].shape
# Out:
# (33, 10)

# %%
df['user']=df['user'].str.strip()
# df['user']

# %%
# Messages by hamza
df['user']=='Hamza Uni'
df[df['user']=='Hamza Uni']
# Out:
#            user             message2   only_date    year  month_num   month  \
# 122   Hamza Uni                 ....  2022-07-03  2022.0        7.0    July
# 123   Hamza Uni   @923095177618 ..sa  2022-07-03  2022.0        7.0    July
# 148   Hamza Uni      <Media omitted>  2022-07-04  2022.0        7.0    July
# 149   Hamza Uni      <Media omitted>  2022-07-04  2022.0        7.0    July
# 150   Hamza Uni      <Media omitted>  2022-07-04  2022.0        7.0    July
# ...         ...                  ...         ...     ...        ...     ...
# 2181  Hamza Uni      <Media omitted>  2023-07-08  2023.0        7.0    July
# 2272  Hamza Uni   Assalam o Alaikum,  2023-08-07  2023.0        8.0  August
# 2282  Hamza Uni    Mujh aj pta lagaa  2023-08-07  2023.0        8.0  August
# 2284  Hamza Uni   Oh..mujha kisi aur  2023-08-07  2023.0        8.0  August
# 2290  Hamza Uni      <Media omitted>  2023-08-19  2023.0        8.0  August
#
#        day  day_name  hour  minute
# 122    3.0    Sunday  11.0    13.0
# 123    3.0    Sunday  11.0    13.0
# 148    4.0    Monday  13.0    40.0
# 149    4.0    Monday  13.0    40.0
# 150    4.0    Monday  13.0    40.0
# ...    ...       ...   ...     ...
# 2181   8.0  Saturday  22.0    46.0
# 2272   7.0    Monday  21.0    19.0
# 2282   7.0    Monday  21.0    19.0
# 2284   7.0    Monday  21.0    20.0
# 2290  19.0  Saturday  16.0    43.0
#
# [222 rows x 10 columns]

# %%
df.groupby('user')['user'].count().sort_values(ascending=False).head()
# Out:
# user
# Fawad                 656
# Usama Uni             504
# Hasham Uni            307
# Hamza Uni             222
# Group Notification     33
# Name: user, dtype: int64

# %%
#total Words
newdf=df[df['user']!='Group Notification']
newdf['message2']=newdf['message2'].str.strip()
words= newdf[newdf['message2']!='<Media omitted>']['message2'].str.split().str.join(' ')
# words.shape
# df['message2'].str.split()
words.count()
# Out:
# <ipython-input-48-eabef8143bac>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['message2']=newdf['message2'].str.strip()
# 1274

# %%
#total Media
newdf=df[df['user']!='Group Notification']
newdf['message2']=newdf['message2'].str.strip()
words= newdf[newdf['message2']=='<Media omitted>']['message2'].str.split().str.join(' ')
# words
words.shape
# df['message2'].str.split()
# words.count()
# Out:
# <ipython-input-49-cdfac2cd41d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['message2']=newdf['message2'].str.strip()
# (415,)

# %%
# word=[]
# for message in df['message2']:
#   word.extend(message.split())

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.8.0

# %%
# emojis = []
# for message in df['message2']:
#   emojis.extend([c for c in message if c in emoji.UNICODE_EMOJI['en']])

# %%
from collections import Counter

# %%
pd.DataFrame(Counter(words).most_common(20))
# Out:
#                  0    1
# 0  <Media omitted>  415

# %%
# !pip install urlextract
# Out:
# Collecting urlextract
#   Downloading urlextract-1.8.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from urlextract) (3.4)
# Collecting uritools (from urlextract)
#   Downloading uritools-4.0.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from urlextract) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from urlextract) (3.12.2)
# Installing collected packages: uritools, urlextract
# Successfully installed uritools-4.0.1 urlextract-1.8.0

# %%
from urlextract import URLExtract
extractor=URLExtract()
#total URL

# %%
df['message2'][0]
# Out:
# ' You added Hasham Uni'

# %%
extractor.find_urls('fawad.comaafsa.comasfa  faad han yr suna')
# Out:
# []

# %%
for message in df['message2']:
  print(message)
  url=(extractor.find_urls(str(message)))
    # links.extend(extract.find_urls(message))
# Out:
#  You added Hasham Uni
#  Fadii left
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  ....
#  @923095177618 ..sa
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Os ka question 2 hua t
#  Nahi...houa
#  Hua to!
#  Ustad phla hua?
#  @923095177618
#  <Media omitted>
#  Kn sa code?
#  Compiler
#  Tokenizer of enter
#  To vo agr kisi na
#  Prsnl bhj dy
#  Logic dekhni
#  To bas tujy zero m
#  Ziada kuch nhai ho
#  😂😂😂😐
#  Hasham way
#  Dikha esi jo dekhn
#  Bt suno?
#  Lab 13 ki kisi ne
#  Last date ha aj!
#  <Media omitted>
#  <Media omitted>
#  😂😂😂😂😂
#  Koi nai
#  Belt he pkri hui
#  Bachat hai
#  😂🥲
#  Us ko bol ye pos
#  <Media omitted>
#  Shirt le aaein wapis
#  https
#  Join krlo😳
#  Fawad pictures se
#  Sari send kari
#  Yr mera se mango
#  App sa koi BAAT h
#  <Media omitted>
#  <Media omitted>
#  Yr numerical computi
#  Freindship ended wit
#  Meanwhile Hasham
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  nahi mza nahi ay
#  Bass Kar paglaaa
#  https
#  <Media omitted>
#  <Media omitted>
#  Haaan haan 4 saal se
#  Ye puch kya rha ha m
#  Tu apni try kr
#  Chor es ko
#  Ye b ha🤡
#  Abaa Waseem koo
#  Subha class ha n
#  Abhi mere damiag
#  Mujha yeh Samj N
#  Research chl rhi ha
#  😄😄😄🤭good one
#  <Media omitted>
#  Mtlb kya ha iska🥹
#  Sara paisa desi
#  <Media omitted>
#  @923349612022 @92311
#  🤭😄
#  And chatnii bhi🫣
#  Haan🥺😂
#  MashaaAllah usama kl
#  InsHallah
#  Aoa
#  <Media omitted>
#  Class join karo
#  Question behj ra
#  No laga ga
#  solve krny k sath
#  G bahi me wait k
#  Awaz hi ni aa rhi
#  Osama class join
#  kr chuka
#  Question lehk ra
#  Taka number bhi l
#  bol he nahi sir k
#  Qchaa
#  Sbr karo
#  Code pr krna ha ya pa
#  Jab bola Nahi ha.
#  Paper
#  ok
#  saths ath bhejna
#  Diwar par
#  aik case kr lo to
#  Yrr tum sb na ha
#  Wah
#  Kya intro tha
#  Khoti k
#  kitna time diya s
#  Vo physical ao g
#  PATA NAHI BATA
#  yar tm kitny frig
#  hasham
#  Ans bhj jldi usama
#  <Media omitted>
#  Oye 1st case kr k
#  Apni bna lo meeting
#  Usama link bhj
#  faid ni
#  Bhj
#  Jaldi
#  Jldi
#  Kr
#  solve kr k bhej d
#  Msla ha bra
#  Rapshon Ka foumul
#  https
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  ttendence
#  Slide num btao
#  Sir na Attendence
#  jo jo join thy
#  Ma bhi tha
#  Sir na Attendence
#  Daim ko kha tha shyd
#  Tu cls n tha to lg gi
#  https
#  <Media omitted>
#  <Media omitted>
#  Status🤤
#  <Media omitted>
#  <Media omitted>
#  Fake real koi pta?
#  Rawalpindi
#  Not isb
#  Not confirmed
#  Real ha but pindi ki
#  Hn shid
#  Bhi se puchta na kl c
#  Tention na lay us
#  Acha ye to pta hi ni
#  Yra mano ya na mano h
#  Reminder for Assignme
# nan
# nan
# nan
#  Question mn ne bhj dy
#  graph={
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  @923111235909
#  <Media omitted>
#  ye mera ha?
#  Kya
#  code?
#  Nahi...mere ha
#  mzy kr phr
#  Tere run houa
#  hn cnfrm ni sai ha ya
#  Graph show houa
#  Nodes hoe hn gye grap
#  Ye kiya ha
#  <Media omitted>
#  Code
#  50 number lgy hn hmza
#  Tsk diya ha
#  A plus bhr o bhr
#  Nai just for practice
#  Hyaaa mazaa...has
#  Wah
#  Hamza bhut genius ha
#  puri cls mn tha atten
#  <Media omitted>
#  <Media omitted>
#  Abaa pataa Nahi l
#  Isi lye to genius kha
#  <Media omitted>
#  Cls ko chorr kl match
#  <Media omitted>
#  Hn ustd tu namaz k ly
#  Cl uni phir khul
#  Dekh le hasham k mhma
#  Nahi
#  Khan chala giya
#  Wo waly mehman aye hu
#  Thursday ko ai g
#  Utanaaa ma masroo
#  😄
#  Nope enjoy kr tu
#  Ohh abi ni aayi💔
#  Hosla kr hamza se tip
#  Ye ek semester bd ja
#  <Media omitted>
#  🤤🤤
#  <Media omitted>
#  https
#  @923349612022
#  Bahi pak to ab f
#  Mn to aao jaon ga🫶...
#  Bhi match pura dekhna
#  Bahi agr jeet ra
#  Na na bshk buri trh h
#  💯Agreed
#  <Media omitted>
#  bas kr k send kr
#  Today is the FREE De
# nan
# nan
# nan
#  kon?
#  Nexusberry
#  Bahi kisi se ku
#  https
#  <Media omitted>
#  <Media omitted>
#  Hosla rakho bah
#  Abhi party shur
#  Jeet jai ga ins
#  <Media omitted>
#  Mad ka؟
#  Yes
#  Tuesday tk time ha i
#  <Media omitted>
#  Mn kh rha na
#  <Media omitted>
#  <Media omitted>
#  ?
#  code kr
#  Beth kr
#  Bsdkaa question mark
#  <Media omitted>
#  <Media omitted>
#  University online?
#  Bsdk..
#  <Media omitted>
#  Mn basketball ground
#  Ok
#  2no mily?
#  Tu kdrr h?
#  <Media omitted>
#  Hmza topper bs kr😂
#  Usama ni nkla?
#  <Media omitted>
#  Summary?
#  Ideas💡 i think
#  <Media omitted>
#  <Media omitted>
#  *Group*
# nan
# nan
# nan
# nan
#  Sap chk kr loo
#  <Media omitted>
#  Today is the FREE De
# nan
# nan
# nan
#  Kdr h?
#  Ye chk kroo
#  https
#  1d
#  2b
#  3c
#  4d
#  5a
#  6b
#  7c
#  8a
#  9c
#  10b
#  <Media omitted>
#  Mery ko nhi pta
#  Aby yr wait
#  <Media omitted>
#  Jldi sunoo
#  Ok
#  This message was
#  <html>
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  Sign
#  Ab jaldi ISS ki b
#  🥹🥹🥹 پگلے رلاے گا
#  Baskwas na Kar...
#  Time Nahi ha
#  Allah ap ka darg
#  Oy hua kisi se?
#  Database wala ki
#  Hm whi krein gye jo k
#  Ohh..warooo daa
#  Tere lya bata hou
#  Backend houi
#  sbr
#  <?php
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  login
#  inseert
#  <!DOCTYPE html>
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  <!DOCTYPE html>
# nan
# nan
# 8">
# equiv="X
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  Assignment bhejo
#  Puri h ye
#  Changes jr lena
#  Chmged kom kon c
#  Database tunhra chang
#  Or b hn chexain chang
#  ..
#  <Media omitted>
#  <Media omitted>
#  Hamza se la lou
#  🔔
#  Wo abaid part 2 ha
#  Hramion group bb
#  Idhr maro
#  Aledha aledha ma
#  Ye bik gye hn sb
#  Hamza to submit krwa
#  Muja kaha hua us
#  Begarto
#  Kis ny kya kha hua
#  Kaha nahi hai
#  Per muja yqeeen
#  😂😂😂
#  Aby kiya bol rha
#  Aio jga reh na r
#  Bhi wo aj any lga th
# nan
#  Phr ni aska😂
#  Or tu us ka wait kr
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  MashaaAllah ❤️
#  Level
#  Bahi hasham Sa r
#  Phla usi ka h
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  https
#  Or khao
#  Bahi ap he hams
#  Yr mn mna krta ye su
#  Mny b le jaty zbrdst
#  <Media omitted>
#  Yeh kis Ka hoste
#  Mujtba
#  Abaid
#  Anyone now??
#  <Media omitted>
#  <Media omitted>
#  Physical kr le
#  Udahr bhi show N
#  Run k option se ja k
#  Waha sa hee kya
#  Sir se puch phrr
#  Pehly dekh apny
#  Developer option
#  Wo sb option on
#  <Media omitted>
#  Omg
#  Ada suna jatuk
#  Parizad transformati
#  Epic 😂
#  Oh ..basdk
#  Yeh tuo mere AJ
#  😂😂😂 yar wesy che
#  Tu ny ktny qatal kye
#  Oy kitny bndy hn cls
#  Abhi nikalana l
#  Sir tapa hua h😂
#  Na na
#  Sir nahi tapa hu
#  Hasham way
#  Ab tera kam hai
#  K tu hmari bhe s
#  Krai
#  Oy mri b kr denaa
#  19742
#  Kasa karou
#  Khud kiya ni ha
#  Bety email sy se
#  Sap ka achar dal
#  Hasham tu kr mai
#  Apna laptop on r
#  Fawad apni stude
#  Hamza ka bhe pta
#  19742 ha agy same h
#  Pass
#  Hasham file taya
#  Chlo g Monday b chut
#  Ab Tuesday se start
#  Jo b gya mra b quiz
#  Ustd koi sheet le an
#  Jo b lana 2 lana❤️
#  <Media omitted>
#  Ye chk kro😂
#  <Media omitted>
#  Three phases of
#  <Media omitted>
#  <Media omitted>
#  @923349612022
#  <Media omitted>
#  POLL
# 5?
# nan
# nan
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Kafi zeda messag
#  Bsdk
#  Hua hai to bhj
#  Once i get the a
#  Bsdk
#  🙄
#  Tera asra
#  Tha 🥲🥲🥲
#  O lul sir sharje
#  To tu urdu bol na
#  Wesy koi bat sunt
#  Yeh tuny dil py l
#  Blkay dil k bjai
#  😂😂😂
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  ?
#  Skilss dekh
#  us ki age k hisab
#  2022 mai wo ms kr
#  r tu kiya chahta
#  Behtreen skills h
#  Mtlb k us ki skills s
#  Kr rha h abhi
#  Bai us k mutabiq
#  Full stack developer
#  ms tk hum bhe etn
#  <Media omitted>
#  chill bawa g chil
#  You don't have to pay
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  Ustd ye chk kroo
#  link nhi ho rh ao
#  2sra chk kr koi
#  <Media omitted>
#  Assignment 3😍
#  Farig sir
#  Bs ek dukh h
#  Usama ki b gum jati n
#  <Media omitted>
#  Sir sa BAAT karta
#  Ab na krna mail
#  Demo dein gy to bol d
#  Udar bhar..Kar do
#  Ma
#  😂
#  Apna kam bntaa Bharr
#  Mwry kitny ban rj
#  Muja smj he. Ahi
#  22
#  Asa swal tu mera
#  Tery kitny
#  Or total kitny ma
#  24
#  50 mai sy?
#  43
#  14 plus kiye to 3
#  38 mai 4 add kiye
#  Yani k nikal jai
#  4?
#  Certificate
#  2 2 k
#  Meray?
#  Vo mujha ni pata
#  Dkh k btaa na mjy b n
#  Far right
#  31
#  Ty
#  hamza sy phada hu
#  us k bhe bta na
#  In ka name ek sth na
#  Allah na akal de
#  Khud bhi to dehk
#  Yeh hasham mn tery st
#  Ik to isa pataya
#  😂😂😂😂😂
#  Hn ve usama😂
#  Hmza in baton ki tens
#  Hmza mar pkr kr sir k
#  😂😂😂😂 yr project r
#  😂is ka mtlb tu kr chu
#  Oa light ha kisi
#  27 ghntu bd ani j
#  Ik parhna pehla
#  Dekh yr is br pakka i
#  Matlab ab mad ka
#  Nishta nishta
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Paper ka time ki
#  Or wed ko he ha
#  1
#  .
#  ..
#  Wed ko ha mad ka
#  Aby bola to ha hn
#  Yes
#  Oyeee...fawad ter
#  Us ne to ni btaya
#  <Media omitted>
#  yrr mujha asa lg
#  Hn hn skta
#  Yeh..kya last pap
#  Oyee light Hain..
#  Hn
#  Ni net se mily
#  Project se related qu
#  PArha he nahi abh
#  Achya mtlb kye to bhj
#  Baki mcqs dekh milty
#  okz
#  mcqs kery?
#  Yr mad k dekh na koi
#  achaaaaaaa caha
#  Ali kn se assign
#  kb kha
#  assessment kha ha
#  Ok
#  hasham way
#  assignment to sha
#  shuru wali
#  Mad Project requ
#  ?
#  yh kiya hai
#  Mtlab project me
#  <Media omitted>
#  <Media omitted>
#  ?
#  assignment pri?
#  yeh wali
#  https
#  Pri hogi tym lg jy ga
#  hasmy send mar wo
#  Iski deadline kya thi
#  71 days pehly
#  Date kya thi L
#  Allah jany
#  Project waly question
#  Nah
#  Ustd kr kuchh
#  <Media omitted>
#  Abi kya kr rhaa?
#  Chai pe rha
#  Abhi tk 4 skide p
#  Sai h lga rh
#  Barish ki kya surat e
#  ho rhi idhr
#  Saii
#  <Media omitted>
#  Barish ho rhi h udr?
#  Abhi ni ho rahi
#  Oky
#  Oyee Numerical ka
#  Aur syllabus Sara
#  Hn
#  Pta nu
#  40 ka hai shid
#  Paper
#  Absolute 40
#  Bisection
# nan
# nan
# nan
# nan
# nan
# nan
#
# nan
# nan
# nan
# nan
#
# nan
# nan
#  <Media omitted>
#  <Media omitted>
#  Koi ghlti hui to btaa
#  Allah bahi ap ka
#  Bhi zinda hn
#  Yr kabhi na kabh
#  Tu khud bht bri g
#  Bhi itni jldi q h tuj
#  G ap kdr??
#  Bachay ni bolty beech
#  Me tujha zindagi
#  Us ka aye na ye t
#  Jitna tu piyara h
#  Ni abi to hmza ki sha
#  🥵
#  Ab aya na line py
#  Bs duaa karo jb
#  Chawal kah kr me
#  Bas bryani ka keh
#  Yr us tym tk shyd hm
#  Tujha especially
#  Khair hai wo hi k
#  Done
#  Bas tu marny ki t
#  Wasiyat  me lehk
#  Bhi isy chrs dein wo
#  Han sai bat bat
#  Fawady jaisa ho g
#  Tu na karo tujha
#  Inna lilihi wa inaa..
#  Isi kye to Bury log z
#  <Media omitted>
#  Agr tym km hua to Lag
#  Take a lesson fr
#  Wese koshish krna k c
#  Ans ajy ga is trh b
#  Num kat b sktaa
#  Bhi hmza ne grp leave
#  Na chroo mlngaa nu🥹
#  Mai kal hamza k f
#  Parhmy
#  😁😂
#  Kya pharnay?
#  🙆‍♂
#  <Media omitted>
#  Numeric
#  Oyee muj sa group
#  <Media omitted>
#  muj sy ho jai e
#  Gyaib Hou jaaa
#  Who the hell u t
#  O paiii bas kr dy
#  Sir bhe sochty ho
#  Kiya to wo buri g
#  Bs next time sir
#  Es liye sir dubar
#  <Media omitted>
#  Well well well
#  A giya unt pahar
#  Solution da
#  Ni kiya
#  Din tk kr ka beh
#  Ok
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  @923447328858 @92
#  ?
#  Queation
#  Regula falsi, bis
#  1 sab k
#  Mily?
#  Hn
#  Paper dupehr ko h
#  Steps agr 5 hon t
#  @923095177618
#  ?
#  Steps kitny hon to n
#  Bilfarz hmy n ki jga
#  Step 6 to ab n ki val
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Uni h koi?
#  Yaar important de
#  Sir wali prh ly jo li
#  Hn
#  Mai
#  <Media omitted>
#  Yr😂
#  Cn k ktny thy ch mid
#  2 ya 3?
#  https
#  Nhi pts
#  Talha keh rha peh
#  Ok
#  Collision a avoi
#  yeh shid
#  pta nahi
#  😂
#  udp and tcp mai h
#  window slide hoti
#  @923447328858
#  Yrr agr ni pata
#  chal baqi bachon
#  CSMA/CD
#  Wireless mn avoid krt
# nan
#  Mid se phly wala h
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Yr in k ans dhndo ni
#  Baki jo ghlt mn mn bh
#  @923111235909 @923095
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Ye lgaya hua or ye mi
#  to none of these
#  Yehi lg rha mjy
#  Nonw of these
#  <Media omitted>
#  <Media omitted>
#  Chorr isy baki dekh
#  Jo pics bhji thi phly
#  none on these bnt
#  Which protocol allows
#  Pv6 machine can find
#  <Media omitted>
#  Hainn
#  Question or h ans or
#  question yehi bnt
#  Yr jo mn ne copy past
#  Jo tuny bhejy mai
#  👏👏
#  <Media omitted>
#  Hn false h us mn 7 h
#  <Media omitted>
#  <Media omitted>
#  baqi sary thk hai
#  ..
#  ..
#  In 2 ka pta ni
#  Hn baki tkrebn
#  <Media omitted>
#  es iimg sy shid a
#  <Media omitted>
#  werna pta nahi fr
#  Na
#  <Media omitted>
#  Prha phly
#  jo ali k mcqs hai
#  wo bhe kr ly na
#  wo bhe bhej dy
#  Same hn
#  nhi sme
#  Knsa ni same?
#  Dekh zra
#  <Media omitted>
#  muja to sary diff
#  ???
#  Yr same hi hn
#  Wese Prh ly prhny to
#  or koi topic bta
#  Yr hasham ne jo bhja
#  Classes imp hn
#  Subneting
#  Crc
#  subnetting to sub
#  Last 2 topic chapter
# nan
#  <Media omitted>
#  osi model
#  4 hn ya 5
#  7
#  to yeh jo 5 hn ye
#  en ko iya kehty
#  Hn sai kh rha tha tu
#  4 b hty or 5
#  Chk kr le name
#  ok
#  BAAT sun
#  Yaar yeh Ali Hass
#  <Media omitted>
#  ?
#  kch thk kuch glat
#  Tuo Sahi wala sol
#  Jaldi
#  ???
#  mcqs k ss upar bh
#  wohi hn
#  Assignments me m
#  Pta ni yra mry b 2 mn
#  Is ke kiya assig
#  Koi idea ha
#  Hn jo b thi hm ne krw
#  Moellim pr
#  Galat na ho
#  Nai usama k to aye hu
#  Chl kl sir se ba
#  Copy paste ka ch
#  Pta ni bta de ga jo b
#  <Media omitted>
#  Web paper
# nan
# nan
# nan
# nan
#  ..Yaar mcqs Yaha p
#  Yeh kis may kha
#  Yr sir ek br mcqs bna
#  Sir na
#  Quiz assignment b dekh
#  Ha
#  Mcqs tuo share kar
#  Important
#  https
#  Baki b dekh phpysql k
#  <Media omitted>
#  Silent message fo
#  <Media omitted>
#  Hn pta ni kn hn wo "So
#  Wakia...
#  <Media omitted>
#  yar es maai kon sa
#  Na kr itna mehnat
#  aby mehnat nahi kr
#  bs bta do model ko
#  No idea
#  takay pochy sir to
#  Chatgbt se pouch
#  wo he wohi keh rha
#  k
#  libraries hain jus
#  Abaa model .last p
#  Waha sa dekh
#  kahan per?
#  use hota
#  yeh
#  <Media omitted>
#  Mujha . tuo keras
#  Jou Ka hum na tuo
#  S hta k🤣
#  😆
#  hmza tuny kb jna?
#  demo deny
#  <Media omitted>
#  <Media omitted>
#  Usman Durrani 2.vcf (f
#  @923111235909
#  Abhi..tuo maa utaa
#  Report ban gyi tuo
#  mai 3 tk joun ga
#  sir thaky hn gy th
#  to kam ho jai ga
#  Wah..kya dmag lagy
#  Kl 10 calls me na
#  Usama tu rhn dy hmza k
#  Iqbal idhar iqbal
#  mai nikla he 3 45t
#  tha kal
#  Tu web ka he pape
#  han na
#  To itni dair kya
#  question galat ho
#  wo dubra kiye phr
#  us ko sochta rha
#  phr wo kiye to phr
#  Koi..fida Nahi..so
#  asort thk hua hai
#  Matlb...A++ grade
#  baqi bhe adi adi l
#  Pta nahi . bs pape
#  Pher savour bnta h
#  khila dain.
#  Savour
#  hasham bhe khush h
#  k hamza khila rha
#  Khilaa dou gaa...y
#  bs khila dain.
#  mai v kha ln ga ab
#  Abhi kehlta ha to
#  <Media omitted>
#  <Media omitted>
#  Kdr? 🥸
#  Ktny marks ka h final?
#  Pta nhi
#  Northern ha cousi
#  Yrr ni agr pata h
#  Hr jagha tera yeh
#  To begrt tu idhr k
#  Tu chup mr
#  Pata raha ho ka p
#  Tu chup kara ga t
#  Bai mai ignore mhi
#  <Media omitted>
#  Seen kr ka jawab
#  Personal message
#  Dekh abhi chup kr
#  <Media omitted>
#  😂😂😂😂😂
#  unho nay pasy whic
#  tu memes which kr
#  hisab braber
#  Hn idr shuru hoja ab😂
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Ab voch krna hi pry ga
#  Memes*
#  <Media omitted>
#  Nahi
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  No idea
#  Kue ma na bhi .2,3
#  <Media omitted>
#  Kise..aur moomen s
#  Okay 😂
#  Usama se pucha to khy
#  Tbhi mna bolna mun
#  Everyone's know my
#  😂
#  Abay...tuo chupp k
#  Hasahm ki BAAT ki
#  Jalwa h tera yahan🥸
#  What a shot🤣
#  Oh acha phr thk ha
#  Per yeh meri bat k
#  <Media omitted>
#  Yr ek bt suno hasham p
#  Sir osmaa imtiaz K
#  Yawr bra late smjh aya
#  Acp pryaduman😎
#  <Media omitted>
#  Nahi...ACP Osama i
#  Hn naw itni mhnt ki to
#  Hasham na abhi tk
#  Has le putar has
#  Mtlb revision rhti h b
#  😂😂😂😂😂😂😂
#  Nahi...reee bass o
#  Bahi jasa ap bs m
#  Hasham bahi ma app
#  Party bdl lya sala
#  Ab hasham ko parna
#  Phr b ni de ga
#  Mtlb ni dkhy ga🥵
#  Paper*
#  🤦‍♂🤦‍♂
#  Bahi vo topper ha
#  Sb choro usama ki
#  Hamza x Hasham *Reunio
#  Lagta ha 4 gpa ka
#  Nechaa sa
#  Phly sir muzamil ki kh
#  Putar pr reha vo
#  Hn naw ab b na aye🥵
#  Overtime lagaa Rah
#  Bro bri mhnt h is kam
#  Waseem se pucho
#  Tuja baraa idea ha
#  Vo sir umer sulta
#  Phela tuo bata
#  😂😂😂😂
#  Ab..wo mateen Ka..
#  Ni wo sada bnda tha hm
#  Aur Sarjeel Ka aga
#  Ye to bry logon ki khd
#  Means
#  Wo ni uthany deta isla
#  Bahi usama profes
#  Bhool ja usy us k nam
#  Mazyyy Ka agaa...O
#  Vo sir pasha ka u
#  Yr usama sadmy mn h ji
#  Usama sir adil k utha
#  Ab istakaraha kr
#  Ab Soch Raha ha...
#  Wasa mast idea ha
#  Yr ab reply kesy kru w
#  Osssss Ka chotaa h
#  Bahi vo level by
#  Tujhy bra pta h 😂😂
#  Tu b jata rha wese us
#  Aur...muuuu ma..
#  Bhi zorr se khench ta
#  Nahi..oyee VC bhi
#  Ab bs karo vo bec
#  Chakooo maar
#  Depression mn hm jaein
#  Ksamyyyy
#  <Media omitted>
#  Prh le bhi memes bhjny
#  Par naho phar* rha
#  Status per lgany s
#  Dekho yar. Uthany
#  Dil jeta naho ja s
#  Chalo utha he lo p
#  <Media omitted>
#  Apna kyu uta raha
#  Uthany se b ni chlta 😂
#  Chao jata hai
#  Kbhi utha k dekhna
#  <Media omitted>
#  <Media omitted>
#  Decision tree
#  Ok
#  Oy ye last slaide kaha
#  Slide*
#  <Media omitted>
#  <Media omitted>
#  @923095177618
#  <Media omitted>
#  Question kon sa?
#  Yaar entropy calcu
#  Hasham ko pta ho s
#  ya fwd ko
#  <Media omitted>
#  Inshallah
#  <Media omitted>
#  This message was d
#  https
#  @923349612022
#  Ye aya kisi ko smj?
#  https
#  yeh last wala hai?
#  KNN k bad wla
#  Hn
#  Us k bd b bhut kuch h
#  <Media omitted>
#  This message was d
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Hmein smja rha ya apna
#  bai jo smj aya wo
#  <Media omitted>
#  Kisi ne testing shuru
#  Youtube uys khein se b
#  <Media omitted>
#  Soo ja
#  Yr aj apun 2 bjy tk py
#  Ye lagta ha nasha
#  Tujy pta h usama " Naa
#  @923349612022
#  Bs khushi hi itni h aj
#  Pta ni jb uni se jan c
#  *Photoshop full cours
# nan
#  *HTML Advanced Progra
# 9n
# nan
#  *Fiverr Full Course*
# nan
# nan
#  *Software Development
# nan
# nan
#  *Adobe Illustrator Cr
# nan
# nan
# nan
# nan
# nan
#  https
#  https
#  React
# nan
# end
# the
#  https
#  Data_Scientist_Nanode
#  Graphic designer need
# nan
#  Gift for my Friends &
# nan
# nan
# nan
# nan
# ZI
# nan
# nan
# nan
#
# nan
# bWYTCToIf
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# F4
# nan
# nan
# nan
# nan
# nan
# 6FPK6E
# nan
# F6
# nan
# KdGt0
# nan
# nan
# nan
#  https
#  This link is for lear
# nan
# nan
#  Internship for Graphi
# nan
#  Aj gham mn 2 bjy tk p
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Ni bhi bs jan chutay 🙏
#  Ye me na baki do
#  Tera mujha pehla
#  Wah bhi itna intellige
#  Hamza ka saat rah
#  Na tng kr hm fyp idea
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Lo question mn ne bhj
#  Hoi?
#  Ye chk kro😂
#  https
#  bahi ap jealous
#  Hamza ap ko afta
#  Yh to pechly saal
#  Yes
#  <Media omitted>
#  Mn ne lgani h apko
#  <Media omitted>
#  https
#  Lazmi kr lo fill
#  summer inter
#  <Media omitted>
#  Ye best tha😂
#  <Media omitted>
#  Oy beghrat PM ni share
#  Han han has ab
#  Begarta
#  Mery uty bandooq r
#  Besharma
#  <Media omitted>
#  <Media omitted>
#  Ni bhi ye waqai behuda
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Assalamualaikum
# nan
#  Usama tera block
#  Mere bhi
#  Kl class timing
#  9 bjy class hai s
#  <Media omitted>
#  Wese 10 se 1 hti ha n
#  To 9 20 h phr
#  Han bs yehi hb
#  Oka
#  Solution tuo send
#  #include <stdio.h>
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  part 2?
#  #include <stdio.h>
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# >start_index; i <= tar
# >y[i] = targs
# >y[i];
# nan
# >avg) += sum / (targs
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  is ka btao
#  <Media omitted>
#  What is the final ste
# nan
# nan
# nan
# nan
# nan
#  <Media omitted>
#  https
#  *Remote Opportunity*
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  https
#  😂
#  FAWAD RAHMAN is inviti
# nan
# nan
# nan
# nan
# nan
#  @923095177618 @9233496
#  Ma gari ma hou...M
#  Acga
#  Wah kiya baat ha
#  Data Outliers
#  1
#  2.false
#  g bahi humbhi cha
#  per hamza k liye o
#  to usi k liye send
#  ok sir sorry
#  A very famous comp
# nan
#
# nan
# Processed data
#  A
#  In any Machine Lea
# nan
# nan
#
# nan
#  B
#  Bhaion tm sy sy me
#  🤣🤣🤣
#  Chup kr ja
#  😎😎😎
#  Kal kitna bja clas
#  Aur kal demo bhi h
#  Jitna baja ap aou
#  <Media omitted>
#  <Media omitted>
#  Bahi...ab *abajeet
#  Tuo
#  Acha 🥱
#  Jawab da do...sir
#  Msg ka
#  Pehla patou khush
#  Aapp kon???
#  Bhabhi ne anay de dya?
#  10 baja ustad
#  <Media omitted>
#  Ye bahi ap ka ps
#  Raat ko suna se p
#  Tuo oss ko choor..
#  Ye brhya tha ustd 😂
#  Wasa chikna ha
#  Ye bhabhi wali bt ghum
#  Muskrat ki waja ky
#  Hn wo to hn lkn bhabhi
#  Astigfriullah bah
#  <Media omitted>
#  Bacha bra khush h bhab
#  Muskrat ???🤔
#  <Media omitted>
#  module 5
#  <Media omitted>
#  chatgpt pr ghlt aaein
#  @923111235909
#  week ?
#  5
#  or 4 week k?
#  wo sb thk hain
#  hn
#  <Media omitted>
#  filter black nahi
#  filter blck kr
#  Shukr kr jo mil g
#  Teri kiya na shuk
#  <Media omitted>
#  <Media omitted>
#  Yar oor kala kr di
#  Tera se lagta ha
#  Ye filter laga le
#  dono send kr
#  video
#  Mera ps ye he ha
#  Vo huzafia se la
#  dusri picture?
#  ok ok done hai
#  Tu na he rola dal
#  bs ok hai ok hai
#  Kr ka behj de
#  ach
#  etna ach mi
#  <Media omitted>
#  @923349612022 ter
#  Mn hamza ka dost bol r
#  <Media omitted>
#  Aha
#  university gya h koi?
#  @923095177618 @9231112
#  Nah
#  Jy ga?
#  Dio nhi
#  ?
#  Dil nhi jany ka
#  Yra ye na ho mn aa jou
#  😂😂😂
#  Bai mai to mji ja
#  Tu sabr kr le agr
#  Tu ja abhi
#  <Media omitted>
#  Lumber 1 university k
#  <Media omitted>
#  Oy ye assignment h koi
#  Sherry ne Kya hua msg
#  Apna se kisi topi
#  Yr bnda tym se bta det
#  Ksmy ajeeb
#  Group dekhna tha n
#  🙄
#  Us nay private to
#  😉
#  Aby yd hi ni
#  Ye to Dekha tha
#  Kya h tu ny?
#  Files hm ne bhji thi k
#  Tanseem shab lite
#  Madam ke group me
#  Nhi
#  Acha wo to phr same Ho
#  ?
#  Nahi sb ka differe
#  Group to naho bnay
#  Karna sb na chat
#  Bhi likhin to ek file
#  Agr txt me conver
#  Pta nhi
#  Hn bhj dein
#  Same hna wo
#  <Media omitted>
#  TEXT ME HA
#  Kiya krna hai es k
#  Tu khali dehk is
#  Ye krna h?
#  <Media omitted>
#  ye dosra text me
#  <Media omitted>
#  <Media omitted>
#  Quiz dya?
#  Mjy yd hi ni rhi😂
#  Tsk tsk tsk
#  Mera saat abhi f
#  Usama hamza Tum ny mj
#  😂
#  https
#  Hamz ka khud mna
#  <Media omitted>
#  Assignment knsi h?
#  Ye sawal sirf hu
#  Bs ye smj k hmza puch
#  Aby waqai koi assignm
#  Task for today
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  Hasham meri v kr
#  <Media omitted>
#  Bahi ki meri deal
#  😍
#  Koi deal sheal n
#  🙄 yani k muja sir
#  First time?
#  hn
#  Bs kr
#  Yr mjy call kr dena k
#  Quiz ki yd ni rhni
#  Okazz
#  Osama
#  Answer and please
#  https
#  Ye scene to usama k g
#  <Media omitted>
#  @923095177618 @92
#  Hamza sotela ha
#  Okay
#  <Media omitted>
#  Osaama
#  Waaa
#  ??
#  Subha..kitna bja
#  6 baja uni me ho
#  App Osamaaa hou..
#  6 30
#  Bahlai ka koi za
#  Bahi group me to
#  Wohi kr rha
#  Ruq jaou
#  Bahi huma asa tr
#  🥹
#  Usy 🇮🇳 ka pta h 🥱
#  <Media omitted>
#  Kr da bahi add y
#  Phly isy to koi add k
#  <Media omitted>
#  Riphah walo se g
#  <Media omitted>
#  Lumber 1 dept
#  Bhi ye last tym Wala
#  4
#  Janay sth khna waps b
#  Suba 5 bjy nklna chay
#  Bahi ap agr in s
#  Aisa hi lg rhaa
#  Usama admin h smj jao
#  Uniform mn ana?
#  Hn
#  Yr sai bt h Best ho g
#  <Media omitted>
#  <Media omitted>
#  Iss msg ko.ik lar
#  Mujha
#  Es nay muja bhe k
#  Yar hum bus 7 mai
#  Bus 5 mai thy
#  Buhut farig bnda
#  Bherhall yeh bhut
#  Es ko tasweerain
#  Way
#  Blkl
#  Ni tera baltqar
#  @923095177618 bah
#  Ye whi h cheekny Wala
#  Haaaa wohi..jou h
#  Tha
#  Chasma wala
#  Kon
#  Block mar phr 😶
#  Kon
#  Pheli fursat
#  Ma kar dya tha
#  Kisaa bnda haa ye
#  Power bank wala
#  Haaaa
#  Hamza ka dost tha
#  Oh achaaaaa
#  Yeh wo lrka
#  Chrass
#
#  <Media omitted>
#  yr ye adil or shabaz
#  Tujy remove kr k
#  Tu dekhy ga jo na
#  🤓
#  tension na le sir isl
#  <Media omitted>
#  Mai sir ko bhejta
#  😂😂😂😂
#  Tag b kr dein >>> was
#  Es picture ko dek
#  Enhy pharkana hai
#  Wese target b yhi hn🤤
#  <Media omitted>
#  Kya scene h universit
#  12bja
#  Islam abbasi offi
#  Teek ha
#  12 15 tk phncho ga mn
#  <Media omitted>
#  Ayee
#  Yar hashamy 1st s
#  Ab edit krny ka t
#  Bahi ap kn ho
#  Fwad
#  ??
#  Chota islam😶
#  .
#  Ponk
#  <Media omitted>
#  <Media omitted>
#  Kl university jao gy 2
#  <Media omitted>
#  Yr koi algorithms b th
#  Sb ne learn Kya huy❤️
#  Osamaa
#  Oyee.
#  Google meet pa mee
#  Jildi kar
#  fwad bna ly ga
#  Ni fwad ni bny ga
#  Yaar
#  Bnou
#  Jaldi
#  Khud bna le na
#  Maa na pher kahi j
#  Movie dehkna?
#  Shutup
#  Mra paise b le aaein q
#  <Media omitted>
#  <Media omitted>
#  Uni ma kon kon ay
#  fawad kal a jana.
#  Hamza bhe a jai
#  ?
#  Chorr dy roz ka h ye
#  https
#  Paper ki tayari
#  oky boss
#  Bahi parsou hamz
#  hamza ko is bt ka pta
#  Wo aj pr raha ha
#  jb ksi ko goli krwani
#  Prh rha ho ga. pa
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Weldone...chota
#  No worries chachu
#  <Media omitted>
#  yeh wali slide ma
#  Pdc coursera kiy
#  Course knsa tha?
#  Sherry na jo bs
#  Ha kiya ye?
#  Whi puch rha k ksna c
#  Coursera se koi cours
#  Bahi mujha pata
#  Hn sir ne kaha tha
#  <Media omitted>
#  Or paper isi me
#  https
#  Iski slides b Kuch hn
#  ay ga isi mn se
#  Pdc ka old paper pkro
#  Ye talent sirf i
#  @923349612022 raheel
#  🤔
#  ismy numericals hein
#  <Media omitted>
#  Bahi ye capabili
#  <Media omitted>
#  Sir na agr ye pa
#  Allah kry aa to jy ye
#  Question 2 dehko
#  Sir na bola tha
#  Sol patana Kya mtlb?
#  Code ke output
#  Consider the fol
#  Kya pta phr mpi mp la
#  To mshkl lg rha ye ay
#  Sir nay mUja kaha
#  tyar kro
#  es ka mtlb yehi h
#  Tu na bhi bola t
#  Tujha misguide k
#  <Media omitted>
#  <Media omitted>
#  *Extreme commerce all
# nan
# nan
# ZI
# nan
# nan
# nan
#
# nan
# bWYTCToIf
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# F4
# nan
# nan
# nan
# nan
# nan
# 6FPK6E
# nan
# F6
# nan
# KdGt0
# nan
# nan
# nan
#  Flutter & Dart
#  The Complete JavaScri
#  React
#  <Media omitted>
#  Amdhal's
# nan
# nan
# nan
#  Solve jb hova so
#  Good luck for the fin
# nan
# nan
# nan
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Question
#  Performance wali slid
#  <Media omitted>
#  <Media omitted>
#  Answer different
#  Ye or h
#  Upr Wala or h
#  Ye Gustafson h wo amd
#  <Media omitted>
#  https
#  for mcqs
#  <Media omitted>
#  <Media omitted>
#  Yr is ki assessment k
#  Idr bhj do mil ni rhi
#  Hamza 60/70
# nan
# nan
# nan
#  File h kdr?
#  Dear all,
# nan
#
#  Sir ny to coursera k
#  Yr slide h Kisi ki pa
#  Jo sir ne prhai thi c
#  sir ny kha tha up
#  pta nahi baqi
#  Ni hui
#  mzy kro phr
#  <Media omitted>
#  Yr ye 1d 2d or 3d Kya
#  Difference Kya h is m
#  Usama tera cours
#  Pouch sir se
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  Bety project ki t
#  Tu khud na kari
#  Ek assignment k ni lg
#  Tery Kisi b quiz k ni
#  Hum asa km karta
#  First tym?
#  <Media omitted>
#  Swaaaa ik bnda ka
#  Ni yr hasham ne b ye
#  Ab koi ni h aisa
#  ❤️❤️
#  <Media omitted>
#  @923349612022 mub
#  Shukrun shukrun ha
#  Bahi ap ko ni de
#  Hamza ap ka group
#  Yeh baaat to hai
#  Hamza na hota to h
#  Very much right🙂
#  Hamza bhabhi k sat
#  Tamg na kro esy
#  <Media omitted>
#  <Media omitted>
#  <Media omitted>
#  [5
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 489
# nan
# nan
# nan
# nan
# nan
# nan
#  Software houses
#  ?
#  <Media omitted>
#  Hamza
#  Teri cv behj do
#  tu apni bhj
#  usi tension na le
#  Best friend ha m
#  <Media omitted>
#  A+
#  Shabash phir asa
#  <Media omitted>
#  https
#  null
#  Yani sir adil chorr gy
#  Assalam o Alaikum,
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#  Hamza tera sabun
#  Mujh aj pta lagaa
#  Sb ko aj he pata
#  Oh..mujha kisi aur
#  <Media omitted>
#  Hamza munir (1989
#  Allah janat nase
#  Bohat acha larka
#  Ameen 🫂
#  <Media omitted>
#  null

# %%
print(url)
# Out:
# []

# %%
x=df['user'].value_counts()
name=x.index
count=x.values
print(name)
print(count)
# Out:
# Index(['Fawad', 'Usama Uni', 'Hasham Uni', 'Hamza Uni', 'Group Notification'], dtype='object')
# [656 504 307 222  33]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(name,count)
plt.xticks(rotation='vertical')
plt.show()

# %%
df
# Out:
#                     user               message2   only_date    year  \
# 0     Group Notification   You added Hasham Uni  2022-06-26  2022.0
# 1     Group Notification             Fadii left  2022-06-26  2022.0
# 2              Usama Uni        <Media omitted>  2022-07-03  2022.0
# 3              Usama Uni        <Media omitted>  2022-07-03  2022.0
# 4              Usama Uni        <Media omitted>  2022-07-03  2022.0
# ...                  ...                    ...         ...     ...
# 2287          Hasham Uni       Allah janat nase  2023-08-19  2023.0
# 2288          Hasham Uni       Bohat acha larka  2023-08-19  2023.0
# 2289               Fawad                Ameen 🫂  2023-08-19  2023.0
# 2290           Hamza Uni        <Media omitted>  2023-08-19  2023.0
# 2291               Fawad                   null  2023-08-20  2023.0
#
#       month_num   month   day  day_name  hour  minute
# 0           6.0    June  26.0    Sunday  20.0    45.0
# 1           6.0    June  26.0    Sunday  20.0    45.0
# 2           7.0    July   3.0    Sunday   1.0    33.0
# 3           7.0    July   3.0    Sunday   1.0    33.0
# 4           7.0    July   3.0    Sunday   1.0    33.0
# ...         ...     ...   ...       ...   ...     ...
# 2287        8.0  August  19.0  Saturday  11.0    57.0
# 2288        8.0  August  19.0  Saturday  11.0    58.0
# 2289        8.0  August  19.0  Saturday  12.0    12.0
# 2290        8.0  August  19.0  Saturday  16.0    43.0
# 2291        8.0  August  20.0    Sunday  17.0    41.0
#
# [2292 rows x 10 columns]

# %%
df.groupby(['month_num','month','year']).count()['message2'].reset_index()
# Out:
#     month_num     month    year  message2
# 0         1.0   January  2023.0       385
# 1         2.0  February  2023.0       260
# 2         3.0     March  2023.0        25
# 3         4.0     April  2023.0        36
# 4         5.0       May  2023.0       261
# 5         6.0      June  2022.0         2
# 6         6.0      June  2023.0       137
# 7         7.0      July  2022.0       176
# 8         7.0      July  2023.0        25
# 9         8.0    August  2023.0        15
# 10       10.0   October  2022.0        51
# 11       11.0  November  2022.0       176
# 12       12.0  December  2022.0       142
